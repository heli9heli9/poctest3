# %%
import os
os.makedirs('/tmp/extract', exist_ok=True)
os.chdir('/tmp/extract')

from graph_notebook.seed.load_query import get_queries
get_queries('gremlin', 's3://neptune-tar-test-055714170610/datasets/queries.tar.gz', 'custom')
